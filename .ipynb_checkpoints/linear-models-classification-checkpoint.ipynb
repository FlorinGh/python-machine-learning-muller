# %% [markdown]
# # Linear models for classification

# %%
from preamble import *
# %matplotlib inline

# %% [markdown]
# **Keywords**:
# * binary classification: a problem in which we have to chose from 2 posibilities
# * decision boundary: the result of the classification model, can be a line, a plane or a hyper plane (multiple features)
# * regularization: a method used to reduce over-fitting; it is usually set up adding a scaled norm of the weight vector; the effect is that the weight vector components will have small values and will have small influences on the classification model
# * loss functions: a metric used to determine how well the training data is fitted by the model
# * linear models for classification: logistic regression, linear support vector machines; these apply by default a L2 regularization (same as ridge)

# %% [markdown]
# ### The forge dataset

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC

X, y = mglearn.datasets.make_forge()

fig, axes = plt.subplots(1, 2, figsize=(17, 7))

for model, ax in zip([LogisticRegression(), LinearSVC()], axes):
    clf = model.fit(X, y)
    
    mglearn.plots.plot_2d_separator(clf, X, fill=False, eps=0.5, ax=ax, alpha=0.7)
    mglearn.discrete_scatter(X[:, 0], X[:, 1], y, ax=ax)
    
    ax.set_xlabel("Feature 0")
    ax.set_ylabel("Feature 1")
    ax.legend()
    ax.set_title("{}".format(clf.__class__.__name__))
